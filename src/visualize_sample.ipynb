# %%
import hypercoast

# filepath = "data/raw/aviris/f240604t01p00r12_rfl/f240604t01p00r12_rfl.hdr"
filepath = "data/raw/aviris/ang20210401t150456_rfl_v2z1/ang20210401t150456_rfl_v2z1"
ds = hypercoast.read_aviris(filepath)
ds
# Out:
# <xarray.Dataset> Size: 8GB
# Dimensions:      (y: 6986, x: 675, wavelength: 425)
# Coordinates:
#   * y            (y) float64 56kB 3.267e+06 3.267e+06 ... 3.254e+06 3.254e+06
#   * x            (x) float64 5kB 6.394e+05 6.394e+05 ... 6.406e+05 6.406e+05
#   * wavelength   (wavelength) float64 3kB 377.1 382.1 ... 2.496e+03 2.501e+03
#     xc           (y, x) float64 38MB ...
#     yc           (y, x) float64 38MB ...
#     spatial_ref  int64 8B ...
# Data variables:
#     reflectance  (y, x, wavelength) float32 8GB ...
# Attributes:
#     units:          unitless
#     _FillValue:     -9999
#     grid_mapping:   crs
#     standard_name:  reflectance
#     long_name:      atmospherically corrected surface reflectance
#     Conventions:    CF-1.6
#     crs:            EPSG:32615

# %%
m = hypercoast.Map()
m.add_aviris(ds, wavelengths=[1000, 700, 400], vmin=0, vmax=0.2)
m.add("spectral")
m
# Out:
# Map(center=[29.4780825, -91.39906500000001], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_…
